# %% [markdown]
# # Randomizer
#
# Who goes first? Let's roll the python dice...

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
# Create a data list of students and topics plus names
students = [
['Analyzing Locality Around San Bernardino County Metrolink Stations','Aneesh and Brandon'],
['Beyond the Surface','Ashley, Kenji, and Michelle'],
['Airbnb Impact in Santa Barbara','Casey and Matt'],
['Heatwave effects on the Coachella Valley','Elaine, Lily and Clarys'],
['Intersecting Risks','Fabian, Adrian and Raul'],
['The Consequences of the 580 Truck Ban','Ethan and Genevieve'],
['Mapping Green Space and the Incomes of Los Angeles','Giovanni, Joshua and Andres'],
['SB 79 Impacts','Maj, Aylin and Aryan'],
['Locating the Gaps','Raegan and Gisselle'],
['Green infrastructure, homelessness, and health','Sam and Cristal'],
['Humboldt County & Housing Stress', 'Thomas']
]

# %%
# add the students to a dataframe
df = pd.DataFrame(students, columns=['Topic','Students'])
  
# print dataframe.
df

# %%
# this randomizes the data using .sample
# frac stands for fraction of the data to return, 
# so frac=1 means to return every row
df = df.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ![drum roll](drum.gif)

# %%
df

# %%
# But wait, one group needs to go first, so let's add them to the top
must_go_first = pd.DataFrame({
    'Topic':'',
    'Students':''
},index=[0])

df=pd.concat([must_go_first,df]).reset_index(drop=True)
df

# %%
# drop based on index position of duplicate group
df = df.drop(7).reset_index(drop=True)
df
